# %% [markdown]
# # EDA

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# Importing the train data

# %%
df=pd.read_csv('C:/Users/Sreyan/Desktop/Republic Day/Plandata_jan18.csv',sep = ',',encoding='mac_roman')
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (16,17,18,19,20,21,22,23,24,26,27,29,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#      State   County     Organization_Name  \
# 0  Alabama  Autauga  Blue Advantage (PPO)
# 1  Alabama  Autauga  Blue Advantage (PPO)
# 2  Alabama  Autauga    Cigna-HealthSpring
# 3  Alabama  Autauga    Cigna-HealthSpring
# 4  Alabama  Autauga    Cigna-HealthSpring
# 5  Alabama  Autauga         VIVA Medicare
# 6  Alabama  Autauga         VIVA Medicare
# 7  Alabama  Autauga         VIVA Medicare
# 8  Alabama  Autauga         VIVA Medicare
# 9  Alabama  Autauga      UnitedHealthcare
#
#                                       Plan_Name    plan_type  \
# 0                 Blue Advantage Complete (PPO)    Local PPO
# 1                  Blue Advantage Premier (PPO)    Local PPO
# 2        Cigna-HealthSpring TotalCare (HMO SNP)    Local HMO
# 3            Cigna-HealthSpring Advantage (HMO)  Local HMO *
# 4            Cigna-HealthSpring Preferred (HMO)    Local HMO
# 5                    VIVA Medicare Select (HMO)  Local HMO *
# 6                   VIVA Medicare Premier (HMO)    Local HMO
# ...

# %%
df.isna().sum()
# Out:
# State                                   0
# County                                  0
# Organization_Name                       0
# Plan_Name                               0
# plan_type                             359
# Monthly_Consolidated_Premium_C_D      183
# Annual_Drug_Deductible               9460
# Drug_Benefit_Type                    9460
# Drug_Benefit_Type_Detail             9460
# Contract_ID                             0
# In_network_MOOP_Amount               2994
# Overall_Star_Rating                     0
# Plan_ID                                 0
# PartD                                 414
# Add_Cvrg_Offrd_in_Gap                9460
# Special_Needs_Plan_Type             38468
# Cardiovascular_Disorders            49710
# Chronic_Heart_Failure               49712
# Dementia                            49707
# Diabetes_Mellitus                   49632
# End_stge_Renal_Disease_dialysis     49681
# HIV_AIDS                            49731
# ...

# %%
df.shape
# Out:
# (49736, 58)

# %%
sns.barplot(x="Extra_Coverage_in_Gap",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x="Increased_Initial_Coverage_Limit",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Filling the cells with NaN values

# %%
df["enrollments_jan18"].fillna(int(-999),inplace=True)

# %%
sns.distplot(df["enrollments_jan18"],bins=500)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df["Cardiovascular_Disorders"].value_counts()
# Out:
# *    26
# Name: Cardiovascular_Disorders, dtype: int64

# %%
sns.barplot(x="Increased_Initial_Coverage_Limit",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Filling the NaN values in the Cardiovascular_Disorders

# %%
df["Cardiovascular_Disorders"].fillna("-999",inplace=True)

# %% [markdown]
# Barplot depicting number of enrollments with Cardiovascular Disorders

# %%
sns.barplot(x="Cardiovascular_Disorders",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Creating Bid_ID by adding Contract_ID, Plan_ID, segment_id

# %%
df["Bid_ID"]=df["Contract_ID"].astype(str)+df["Plan_ID"].astype(str)+df["segment_id"].astype(str)

# %%
df["Bid_ID"].nunique()
# Out:
# 3259

# %%
df["Plan_Name"].nunique()
# Out:
# 1824

# %%
df["Plan_ID"].nunique()
# Out:
# 228

# %%
grouped=df.groupby("Bid_ID")["enrollments_jan18"].mean().reset_index()

# %%
grouped.columns
# Out:
# Index(['Bid_ID', 'enrollments_jan18'], dtype='object')

# %%
grouped.head()
# Out:
#     Bid_ID  enrollments_jan18
# 0  H002210        1018.416667
# 1  H002840        2245.666667
# 2  H002870          81.000000
# 3  H002881         144.179104
# 4  H002882         777.333333

# %%
plt.figure(figsize=(25,25))
sns.distplot(grouped["enrollments_jan18"])
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Finding the mean enrollments across all the Bid_IDs

# %%
grouped["enrollments_jan18"].mean()
# Out:
# 1211.6803492975398

# %% [markdown]
# Maximumm Enrollment

# %%
grouped["enrollments_jan18"].max()
# Out:
# 98134.0

# %% [markdown]
# Number of unique Organisations on basis of their names.

# %%
df["Organization_Name"].nunique()
# Out:
# 325

# %%
df["TotalEstimatedAnnualCost"].value_counts()
# Out:
# 0    49736
# Name: TotalEstimatedAnnualCost, dtype: int64

# %% [markdown]
# Checking the correlation

# %%
df.corr()
# Out:
#                                    Plan_ID  Crdiovsculr_Disordrs_Diabetes  \
# Plan_ID                           1.000000                            NaN
# Crdiovsculr_Disordrs_Diabetes          NaN                            NaN
# National_PDP                           NaN                            NaN
# Tiers_Not_Subject_to_Deductible7       NaN                            NaN
# SSA_State_County_Code            -0.078670                            NaN
# FIPS_State_County_Code           -0.085424                            NaN
# star_rating                       0.119927                            NaN
# segment_id                        0.032708                            NaN
# TotalEstimatedAnnualCost               NaN                            NaN
# enrollments_jan18                 0.018560                            NaN
#
#                                   National_PDP  \
# Plan_ID                                    NaN
# Crdiovsculr_Disordrs_Diabetes              NaN
# ...

# %%
df.shape
# Out:
# (49736, 59)

# %%
df[df["MMP"]=="Yes"]
# Out:
#                 State          County  \
# 2537       California     Los Angeles
# 2581       California     Los Angeles
# 2613       California     Los Angeles
# 2614       California     Los Angeles
# 2615       California     Los Angeles
# 2718       California          Orange
# 2767       California       Riverside
# 2782       California       Riverside
# 2844       California  San Bernardino
# 2862       California  San Bernardino
# 2864       California       San Diego
# 2885       California       San Diego
# 2887       California       San Diego
# 2902       California       San Diego
# 2944       California       San Mateo
# 2971       California     Santa Clara
# 2972       California     Santa Clara
# 9420         Illinois       Champaign
# 9438         Illinois       Christian
# 9497         Illinois            Cook
# 9498         Illinois            Cook
# 9499         Illinois            Cook
# 9510         Illinois            Cook
# ...

# %% [markdown]
# Checking the number of Plans with Mediacare and Medicaid Plan

# %%
df["MMP"].value_counts()
# Out:
# Yes    359
# Name: MMP, dtype: int64

# %%
df["MMP"].fillna("-999",inplace=True)

# %%
sns.barplot(x="MMP",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Special Need Plans

# %%
df["snp"].fillna("-999",inplace=True)

# %%
sns.barplot(x="snp",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Plan types

# %%
df["plan_type_p"].value_counts()
# Out:
# HMO                              17876
# Local PPO                         8979
# Regional PPO                      6452
# HMOPOS                            3180
# 1876 Cost                         2167
# PFFS                              1263
# Medicare-Medicaid Plan HMO         354
# Medicare-Medicaid Plan HMOPOS        5
# Name: plan_type_p, dtype: int64

# %%
df["plan_type"].value_counts()
# Out:
# Local HMO         21056
# Local PPO          8979
# Regional PPO       6452
# Local HMO *        2491
# Regional PPO *     2350
# Cost               2167
# Cost *             2149
# Local PPO *        1333
# PFFS               1263
# PFFS *              954
# MSA *               183
# Name: plan_type, dtype: int64

# %% [markdown]
# Plan type and respective number of enrollments

# %%
plt.figure(figsize=(25,25))
sns.barplot(x="plan_type",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(25,25))
sns.barplot(x="plan_type_p",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df[df["plan_type_p"]=="Medicare-Medicaid Plan HMO"]["plan_type"].value_counts()
# Out:
# Series([], Name: plan_type, dtype: int64)

# %%
df[df["plan_type"].isna()==True]["plan_type_p"].value_counts()
# Out:
# Medicare-Medicaid Plan HMO       354
# Medicare-Medicaid Plan HMOPOS      5
# Name: plan_type_p, dtype: int64

# %% [markdown]
# Special Need Plans

# %%
df["Special_Needs_Plan"].value_counts()
# Out:
# No     29008
# Yes    11268
# Name: Special_Needs_Plan, dtype: int64

# %%
df["snp"].value_counts()
# Out:
# -999    38468
# Yes     11268
# Name: snp, dtype: int64

# %% [markdown]
# Differnt benefit types

# %%
df["Benefit_Type"].value_counts()
# Out:
# Enhanced Alternative               27742
# Defined Standard Benefit            6222
# Basic Alternative                   5635
# Actuarially Equivalent Standard      677
# Name: Benefit_Type, dtype: int64

# %% [markdown]
# Different Drug Benefit types

# %%
df["Drug_Benefit_Type"].value_counts()
# Out:
# Enhanced    27742
# Basic       12534
# Name: Drug_Benefit_Type, dtype: int64

# %%
df["Drug_Benefit_Type_Detail"].value_counts()
# Out:
# EA    27742
# DS     6222
# BA     5635
# AE      677
# Name: Drug_Benefit_Type_Detail, dtype: int64

# %% [markdown]
# National PDP

# %%
df["National_PDP"].isna().sum()
# Out:
# 49736

# %% [markdown]
# PartD Basic Premiums

# %%
df["PartD_Basic_Premium3_"]=(df["PartD_Basic_Premium3"][:0] + df["PartD_Basic_Premium3"][1:])

# %%
df["PartD_Basic_Premium3_"].isna().sum()
# Out:
# 49736

# %%
df["PartD_Basic_Premium3"].fillna("$-999",inplace=True)

# %%
import re
demand=[]

for i, row in df.iterrows():
    demand.append(re.sub('[!@#$]', '', row["PartD_Basic_Premium3"]))

# %%
lowa=[]
for i in range(0,len(demand)):
    lowa.append(float(demand[i]))

# %%
df[df["PartD_Basic_Premium3"].isna()==True]["PartD_Prm_oblgtn_50_prm_assist"].value_counts()
# Out:
# Series([], Name: PartD_Prm_oblgtn_50_prm_assist, dtype: int64)

# %%
df[df["PartD_Basic_Premium3"].isna()==True]["enrollments_jan18"].mean()
# Out:
# nan

# %%
lol=df[df["PartD_Basic_Premium3"].isna()==False]

# %%
plt.figure(figsize=(25,25))
sns.distplot(lowa)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
lol["PartD_Basic_Premium3"]
# Out:
# 0        $33.20
# 1        $61.00
# 2        $16.60
# 3         $-999
# 4         $0.00
# 5         $-999
# 6        $70.50
# 7        $30.60
# 8         $0.00
# 9        $30.40
# 10        $0.00
# 11       $23.10
# 12       $16.70
# 13       $30.60
# 14       $30.60
# 15       $22.50
# 16       $31.80
# 17        $-999
# 18       $27.60
# 19        $0.00
# 20       $61.00
# 21       $16.60
# 22        $-999
# 23        $0.00
# 24        $-999
# 25       $70.50
# 26       $30.60
# 27        $0.00
# 28       $30.40
# 29        $0.00
#           ...
# 49706     $0.00
# 49707    $36.70
# 49708    $35.00
# 49709     $-999
# 49710    $74.30
# 49711     $-999
# 49712    $26.70
# 49713    $29.00
# 49714    $24.10
# 49715    $22.20
# 49716     $-999
# 49717    $15.50
# 49718    $36.00
# 49719     $-999
# 49720    $29.40
# 49721     $-999
# 49722    $25.10
# 49723     $-999
# 49724    $25.10
# 49725     $-999
# 49726    $25.10
# 49727     $-999
# 49728    $25.10
# 49729     $-999
# ...

# %% [markdown]
# Tiers are not subject to Deductible

# %%
df["Tiers_Not_Subject_to_Deductible7"].value_counts()
# Out:
# 1.0    19663
# Name: Tiers_Not_Subject_to_Deductible7, dtype: int64

# %%
df["Tiers_Not_Subject_to_Deductible7"].fillna(0,inplace=True)

# %% [markdown]
# Barplot for tiers not subject to deductibles

# %%
sns.barplot(x="Tiers_Not_Subject_to_Deductible7",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Increased Initial Coverage Limit

# %%
df["Increased_Initial_Coverage_Limit"].value_counts()
# Out:
# Y    10
# Name: Increased_Initial_Coverage_Limit, dtype: int64

# %%
df["Increased_Initial_Coverage_Limit"].fillna(0,inplace=True)

# %%
sns.barplot(x="Increased_Initial_Coverage_Limit",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df["Extra_Coverage_in_Gap"].value_counts()
# Out:
# Y    9701
# Name: Extra_Coverage_in_Gap, dtype: int64

# %%
df["Extra_Coverage_in_Gap"].fillna(0,inplace=True)

# %%
sns.barplot(x="Extra_Coverage_in_Gap",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Star Ratings of the Plans

# %%
df[df["star_rating"].isna()==True]
# Out:
#                State      County                         Organization_Name  \
# 13           Alabama     Autauga                          SIMPRA Advantage
# 14           Alabama     Autauga                          SIMPRA Advantage
# 32           Alabama     Baldwin                          SIMPRA Advantage
# 33           Alabama     Baldwin                          SIMPRA Advantage
# 43           Alabama     Barbour                          UnitedHealthcare
# 44           Alabama     Barbour                          UnitedHealthcare
# 45           Alabama     Barbour                          UnitedHealthcare
# 46           Alabama     Barbour                          SIMPRA Advantage
# 47           Alabama     Barbour                          SIMPRA Advantage
# 60           Alabama        Bibb                          SIMPRA Advantage
# 61           Alabama        Bibb                          SIMPRA Advantage
# ...

# %%
df["star_rating"].fillna(999,inplace=True)

# %%
plt.figure(figsize=(25,25))
sns.barplot(x="star_rating",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df["Overall_Star_Rating"].value_counts()
# Out:
# 4 Stars                        19077
# 3.5 Stars                      15860
# 4.5 Stars                       5718
# 3 Stars                         2967
# Plan too new to be measured     2645
# 5 Stars                         1313
# 2.5 Stars                        983
# Not enough data available        763
# Not Applicable                   359
# 2 Stars                           51
# Name: Overall_Star_Rating, dtype: int64

# %%
df["star_rating"].value_counts()
# Out:
# 4.0      19077
# 3.5      15860
# 4.5       5718
# 999.0     3767
# 3.0       2967
# 5.0       1313
# 2.5        983
# 2.0         51
# Name: star_rating, dtype: int64

# %% [markdown]
# Monthly Consolidated Premium

# %%
df[df["Monthly_Consolidated_Premium_C_D"].isna()==True]["Overall_Star_Rating"].value_counts()
# Out:
# 3.5 Stars                    144
# Not enough data available     39
# Name: Overall_Star_Rating, dtype: int64

# %%
df[df["Monthly_Consolidated_Premium_C_D"]=="$0.00"]["Overall_Star_Rating"].value_counts()
# Out:
# 4 Stars                        6597
# 3.5 Stars                      4370
# 4.5 Stars                      1251
# 3 Stars                         981
# Plan too new to be measured     735
# Not Applicable                  359
# 2.5 Stars                       278
# 5 Stars                         121
# Not enough data available        77
# 2 Stars                          20
# Name: Overall_Star_Rating, dtype: int64

# %% [markdown]
# Plans offering PartD

# %%
df["PartD"].value_counts()
# Out:
# Yes    39862
# No      9460
# Name: PartD, dtype: int64

# %%
df["PartD"].fillna("Hi",inplace=True)

# %%
sns.barplot(x="PartD",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df[df["PartD"]=="Hi"]["segment_id"].value_counts()
# Out:
# 0    414
# Name: segment_id, dtype: int64

# %%
df[df["PartD"]=="No"].shape
# Out:
# (9460, 60)

# %%
df[(df.PartD=="Yes") & (df.PartD_Total_Premium5=="$0.00")]["PartD_Prm_oblgtn_25_prm_assist"]
# Out:
# 4        $0.00
# 8        $0.00
# 10       $0.00
# 19       $0.00
# 23       $0.00
# 27       $0.00
# 29       $0.00
# 36       $0.00
# 43       $0.00
# 49       $0.00
# 52       $0.00
# 56       $0.00
# 57       $0.00
# 63       $0.00
# 74       $0.00
# 75       $0.00
# 77       $0.00
# 91       $0.00
# 110      $0.00
# 136      $0.00
# 140      $0.00
# 144      $0.00
# 145      $0.00
# 146      $0.00
# 163      $0.00
# 169      $0.00
# 175      $0.00
# 191      $0.00
# 207      $0.00
# 225      $0.00
#          ...
# 49158    $0.00
# 49178    $0.00
# 49196    $0.00
# 49212    $0.00
# 49228    $0.00
# 49247    $0.00
# 49266    $0.00
# 49291    $0.00
# 49333    $0.00
# 49364    $0.00
# 49378    $0.00
# 49395    $0.00
# 49423    $0.00
# 49450    $0.00
# 49463    $0.00
# 49483    $0.00
# 49500    $0.00
# 49513    $0.00
# 49529    $0.00
# 49544    $0.00
# 49557    $0.00
# 49575    $0.00
# 49587    $0.00
# 49604    $0.00
# 49622    $0.00
# 49639    $0.00
# 49655    $0.00
# ...

# %%
df[df["PartD_Total_Premium5"]=="$0.00"]
# Out:
#                State      County           Organization_Name  \
# 4            Alabama     Autauga          Cigna-HealthSpring
# 8            Alabama     Autauga               VIVA Medicare
# 10           Alabama     Autauga            UnitedHealthcare
# 19           Alabama     Baldwin        Blue Advantage (PPO)
# 23           Alabama     Baldwin          Cigna-HealthSpring
# 27           Alabama     Baldwin               VIVA Medicare
# 29           Alabama     Baldwin            UnitedHealthcare
# 36           Alabama     Baldwin  Arcadian Health Plan, Inc.
# 43           Alabama     Barbour            UnitedHealthcare
# 49           Alabama     Barbour              Aetna Medicare
# 52           Alabama        Bibb        Blue Advantage (PPO)
# 56           Alabama        Bibb          Cigna-HealthSpring
# 57           Alabama        Bibb            UnitedHealthcare
# 63           Alabama        Bibb  Arcadian Health Plan, Inc.
# ...

# %%
df[df["PartD"]=="Hi"]
# Out:
#                 State          County  \
# 2335          Arizona        Maricopa
# 2486       California          Fresno
# 2519       California            Kern
# 2536       California           Kings
# 2537       California     Los Angeles
# 2555       California     Los Angeles
# 2581       California     Los Angeles
# 2612       California     Los Angeles
# 2613       California     Los Angeles
# 2614       California     Los Angeles
# 2615       California     Los Angeles
# 2626       California          Madera
# 2640       California          Merced
# 2643       California        Monterey
# 2670       California          Orange
# 2717       California          Orange
# 2718       California          Orange
# 2767       California       Riverside
# 2781       California       Riverside
# 2782       California       Riverside
# 2814       California  San Bernardino
# 2844       California  San Bernardino
# 2861       California  San Bernardino
# ...

# %%
df[df["PartD"]=="Hi"]["PartD_Drug_Deductible"].isna().sum()
# Out:
# 0

# %%
df[df["segment_id"]==0]
# Out:
#                State    County                      Organization_Name  \
# 0            Alabama   Autauga                   Blue Advantage (PPO)
# 1            Alabama   Autauga                   Blue Advantage (PPO)
# 2            Alabama   Autauga                     Cigna-HealthSpring
# 3            Alabama   Autauga                     Cigna-HealthSpring
# 5            Alabama   Autauga                          VIVA Medicare
# 6            Alabama   Autauga                          VIVA Medicare
# 7            Alabama   Autauga                          VIVA Medicare
# 9            Alabama   Autauga                       UnitedHealthcare
# 10           Alabama   Autauga                       UnitedHealthcare
# 11           Alabama   Autauga                       UnitedHealthcare
# 12           Alabama   Autauga                       UnitedHealthcare
# 13           Alabama   Autauga                       SIMPRA Advantage
# ...

# %%
df[df["In_network_MOOP_Amount"].isna()==True]
# Out:
#                State      County                    Organization_Name  \
# 16           Alabama     Autauga             Humana Insurance Company
# 38           Alabama     Baldwin             Humana Insurance Company
# 180          Alabama        Clay             Humana Insurance Company
# 354          Alabama     Fayette             Humana Insurance Company
# 506          Alabama   Limestone             Humana Insurance Company
# 554          Alabama     Madison             Humana Insurance Company
# 605          Alabama      Mobile             Humana Insurance Company
# 631          Alabama  Montgomery             Humana Insurance Company
# 673          Alabama    Randolph             Humana Insurance Company
# 708          Alabama      Shelby             Humana Insurance Company
# 754          Alabama   Talladega             Humana Insurance Company
# 838         Arkansas    Arkansas             Humana Insurance Company
# ...

# %% [markdown]
# Annual Drug Deductible

# %%
lolol=df[df["Annual_Drug_Deductible"].isna()==False]

# %%
lolol.isna().sum()
# Out:
# State                                   0
# County                                  0
# Organization_Name                       0
# Plan_Name                               0
# plan_type                             359
# Monthly_Consolidated_Premium_C_D        0
# Annual_Drug_Deductible                  0
# Drug_Benefit_Type                       0
# Drug_Benefit_Type_Detail                0
# Contract_ID                             0
# In_network_MOOP_Amount               1622
# Overall_Star_Rating                     0
# Plan_ID                                 0
# PartD                                   0
# Add_Cvrg_Offrd_in_Gap                   0
# Special_Needs_Plan_Type             29008
# Cardiovascular_Disorders                0
# Chronic_Heart_Failure               40252
# Dementia                            40247
# Diabetes_Mellitus                   40172
# End_stge_Renal_Disease_dialysis     40221
# HIV_AIDS                            40271
# ...

# %%
df[df["Annual_Drug_Deductible"].isna()==True]["enrollments_jan18"].max()
# Out:
# 13816.0

# %%
df[df["Monthly_Consolidated_Premium_C_D"].isna()==True]
# Out:
#            State       County                        Organization_Name  \
# 25900   New York       Albany                          MVP HEALTH CARE
# 26067   New York       Broome                          MVP HEALTH CARE
# 26137   New York       Cayuga                          MVP HEALTH CARE
# 26200   New York      Chemung                          MVP HEALTH CARE
# 26236   New York     Chenango                          MVP HEALTH CARE
# 26259   New York      Clinton                          MVP HEALTH CARE
# 26290   New York     Columbia                          MVP HEALTH CARE
# 26318   New York     Cortland                          MVP HEALTH CARE
# 26350   New York     Delaware                          MVP HEALTH CARE
# 26374   New York     Dutchess                          MVP HEALTH CARE
# 26450   New York        Essex                          MVP HEALTH CARE
# 26469   New York     Franklin                          MVP HEALTH CARE
# ...

# %%
df[df["plan_type"]=="MSA *"]
# Out:
#            State       County                        Organization_Name  \
# 25900   New York       Albany                          MVP HEALTH CARE
# 26067   New York       Broome                          MVP HEALTH CARE
# 26137   New York       Cayuga                          MVP HEALTH CARE
# 26200   New York      Chemung                          MVP HEALTH CARE
# 26236   New York     Chenango                          MVP HEALTH CARE
# 26259   New York      Clinton                          MVP HEALTH CARE
# 26290   New York     Columbia                          MVP HEALTH CARE
# 26318   New York     Cortland                          MVP HEALTH CARE
# 26350   New York     Delaware                          MVP HEALTH CARE
# 26374   New York     Dutchess                          MVP HEALTH CARE
# 26450   New York        Essex                          MVP HEALTH CARE
# 26469   New York     Franklin                          MVP HEALTH CARE
# ...

# %%
df["plan_type"].value_counts()
# Out:
# Local HMO         21056
# Local PPO          8979
# Regional PPO       6452
# Local HMO *        2491
# Regional PPO *     2350
# Cost               2167
# Cost *             2149
# Local PPO *        1333
# PFFS               1263
# PFFS *              954
# MSA *               183
# Name: plan_type, dtype: int64

# %% [markdown]
# MOOP

# %%
df[df["In_network_MOOP_Amount"].isna()==True]
# Out:
#                State      County                    Organization_Name  \
# 16           Alabama     Autauga             Humana Insurance Company
# 38           Alabama     Baldwin             Humana Insurance Company
# 180          Alabama        Clay             Humana Insurance Company
# 354          Alabama     Fayette             Humana Insurance Company
# 506          Alabama   Limestone             Humana Insurance Company
# 554          Alabama     Madison             Humana Insurance Company
# 605          Alabama      Mobile             Humana Insurance Company
# 631          Alabama  Montgomery             Humana Insurance Company
# 673          Alabama    Randolph             Humana Insurance Company
# 708          Alabama      Shelby             Humana Insurance Company
# 754          Alabama   Talladega             Humana Insurance Company
# 838         Arkansas    Arkansas             Humana Insurance Company
# ...

# %%
df[df["In_network_MOOP_Amount"].isna()==True]["plan_type"].value_counts()
# Out:
# PFFS      1263
# PFFS *     954
# Cost *     235
# MSA *      183
# Name: plan_type, dtype: int64

# %%
df[df["In_network_MOOP_Amount"]=="$0.00"]
# Out:
#             State          County             Organization_Name  \
# 2549   California     Los Angeles             Anthem Blue Cross
# 2592   California     Los Angeles              SCAN Health Plan
# 2593   California     Los Angeles              SCAN Health Plan
# 2604   California     Los Angeles  Central Health Medicare Plan
# 2645   California        Monterey            Aspire Health Plan
# 2769   California       Riverside              SCAN Health Plan
# 2770   California       Riverside              SCAN Health Plan
# 2846   California  San Bernardino              SCAN Health Plan
# 2847   California  San Bernardino              SCAN Health Plan
# 2855   California  San Bernardino  Central Health Medicare Plan
# 2956   California     Santa Clara             Anthem Blue Cross
# 3035   California         Ventura  Central Health Medicare Plan
# 14175   Louisiana    East Carroll     Vantage Health Plan, Inc.
# 14810   Louisiana    West Carroll     Vantage Health Plan, Inc.
# ...

# %%
df["In_network_MOOP_Amount"].value_counts()
# Out:
# $6,700.00    23665
# $3,400.00     6462
# $4,500.00     1847
# $5,900.00     1583
# $3,000.00     1514
# $4,000.00     1295
# $4,900.00     1292
# $5,500.00     1064
# $5,000.00      809
# $3,250.00      780
# $5,400.00      717
# $6,000.00      604
# $3,500.00      433
# $6,400.00      422
# $4,700.00      343
# $3,900.00      319
# $6,200.00      210
# $0.00          210
# $6,500.00      206
# $3,750.00      187
# $4,100.00      186
# $4,800.00      186
# $3,800.00      174
# $5,700.00      165
# $3,600.00      155
# $4,200.00      149
# $4,400.00      149
# $2,900.00      145
# $3,950.00      143
# $4,300.00      142
#              ...
# $500.00         21
# $4,250.00       20
# $5,950.00       19
# $6,300.00       17
# $2,800.00       17
# $5,650.00       14
# $6,590.00       14
# $5,750.00       12
# $2,600.00       12
# $3,350.00       12
# $1,000.00       12
# $5,550.00       10
# $3,300.00        9
# $400.00          7
# $5,600.00        7
# $2,300.00        7
# ...

# %% [markdown]
# Additional Drug Coverage offered in Gap

# %%
df["Add_Cvrg_Offrd_in_Gap"].value_counts()
# Out:
# No     30583
# Yes     9693
# Name: Add_Cvrg_Offrd_in_Gap, dtype: int64

# %% [markdown]
# Plans with PartD basic premium below regional benchmark

# %%
df["PartD_Basic_Prm_Blw_Rgnl_bnchmrk"].value_counts()
# Out:
# Below Regional Benchmark    9513
# Name: PartD_Basic_Prm_Blw_Rgnl_bnchmrk, dtype: int64

# %%
df["PartD_Basic_Prm_Blw_Rgnl_bnchmrk"].fillna(0,inplace=True)

# %% [markdown]
# Plans with and without PartD basic premium below regional benchmark

# %%
sns.barplot(x="PartD_Basic_Prm_Blw_Rgnl_bnchmrk",y="enrollments_jan18", data=df)
# Out:
# C:\Users\Sreyan\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df[df["plan_type"]=="Cost *"]["In_network_MOOP_Amount"].value_counts()
# Out:
# $3,000.00    490
# $6,700.00    490
# $4,000.00    385
# $3,400.00    370
# $6,000.00    108
# $4,500.00     71
# Name: In_network_MOOP_Amount, dtype: int64

# %%
df[(df.In_network_MOOP_Amount.isna()==True) & (df.plan_type=="PFFS *")]
# Out:
#                State      County                    Organization_Name  \
# 838         Arkansas    Arkansas             Humana Insurance Company
# 854         Arkansas      Ashley             Humana Insurance Company
# 869         Arkansas      Baxter  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 876         Arkansas      Baxter             Humana Insurance Company
# 893         Arkansas      Benton  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 900         Arkansas      Benton             Humana Insurance Company
# 917         Arkansas       Boone  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 972         Arkansas     Carroll  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 979         Arkansas     Carroll             Humana Insurance Company
# 1010        Arkansas       Clark  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 1045        Arkansas    Cleburne  ARKANSAS BLUE CROSS AND BLUE SHIELD
# 1053        Arkansas    Cleburne             Humana Insurance Company
# ...

# %%
df[df["PartD"].isna()==True]["PartD_Basic_Premium3"]
# Out:
# Series([], Name: PartD_Basic_Premium3, dtype: object)

# %% [markdown]
# MOOP and Additional Coverage offered in Gap

# %%
df[df['In_network_MOOP_Amount'].isna()==True]["Add_Cvrg_Offrd_in_Gap"].value_counts()
# Out:
# No     1263
# Yes     359
# Name: Add_Cvrg_Offrd_in_Gap, dtype: int64

# %%
df[(df.In_network_MOOP_Amount.isna()==True) & (df.Add_Cvrg_Offrd_in_Gap=="No")]["PartD"].value_counts()
# Out:
# Yes    1263
# Name: PartD, dtype: int64

# %%
df[(df.In_network_MOOP_Amount.isna()==True) & (df.Add_Cvrg_Offrd_in_Gap.isna()==True)]["PartD"].value_counts()
# Out:
# No    1372
# Name: PartD, dtype: int64

# %%
df[df["Add_Cvrg_Offrd_in_Gap"].isna()==True]
# Out:
#                State    County         Organization_Name  \
# 3            Alabama   Autauga        Cigna-HealthSpring
# 5            Alabama   Autauga             VIVA Medicare
# 17           Alabama   Autauga  Humana Insurance Company
# 22           Alabama   Baldwin        Cigna-HealthSpring
# 24           Alabama   Baldwin             VIVA Medicare
# 39           Alabama   Baldwin  Humana Insurance Company
# 50           Alabama   Barbour  Humana Insurance Company
# 55           Alabama      Bibb        Cigna-HealthSpring
# 65           Alabama      Bibb  Humana Insurance Company
# 70           Alabama    Blount        Cigna-HealthSpring
# 72           Alabama    Blount             VIVA Medicare
# 83           Alabama    Blount  Humana Insurance Company
# 87           Alabama   Bullock             VIVA Medicare
# 97           Alabama   Bullock  Humana Insurance Company
# 103          Alabama    Butler  Humana Insurance Company
# ...

# %% [markdown]
# PartD and Additional Coverage offered in Gap

# %%
df[df["Add_Cvrg_Offrd_in_Gap"].isna()==True]["PartD"].value_counts()
# Out:
# No    9460
# Name: PartD, dtype: int64

# %%
df[df["PartD"]=="Yes"]["Add_Cvrg_Offrd_in_Gap"].value_counts()
# Out:
# No     30543
# Yes     9319
# Name: Add_Cvrg_Offrd_in_Gap, dtype: int64

# %%
df["Add_Cvrg_Offrd_in_Gap"].value_counts()
# Out:
# No     30583
# Yes     9693
# Name: Add_Cvrg_Offrd_in_Gap, dtype: int64

# %%
df[df["PartD"]=="Yes"]["PartD_Total_Premium5"].value_counts()
# Out:
# $0.00      10009
# $25.10       448
# $34.80       448
# $34.30       434
# $30.60       426
# $31.20       424
# $30.10       400
# $24.00       379
# $24.50       348
# $32.00       314
# $25.20       301
# $26.70       300
# $26.00       299
# $24.10       298
# $25.50       274
# $22.60       270
# $26.90       269
# $29.10       261
# $21.40       260
# $4.60        254
# $15.70       254
# $39.00       253
# $29.00       252
# $15.00       252
# $40.00       249
# $30.70       248
# $24.30       245
# $22.90       243
# $27.60       239
# $31.40       233
#            ...
# $13.60         1
# $11.40         1
# $8.80          1
# $76.00         1
# $50.80         1
# $6.10          1
# $28.60         1
# $35.20         1
# $83.10         1
# $44.80         1
# $46.50         1
# $4.40          1
# $12.80         1
# $13.10         1
# $42.50         1
# $47.80         1
# $12.30         1
# $59.00         1
# $85.00         1
# $104.10        1
# $63.00         1
# ...
